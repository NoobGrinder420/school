# %% [markdown]
# The algorithm below shows how to calculate the remainder when a positive integer dividend is divided by another positive integer divisor:
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# As can be seen, a flowchart is a more visual way of presenting an algorithm and may be easier to understand than a long series of steps. Each step is represented by a symbol and the order in which steps are followed is shown using flow lines or arrows.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# By using a selection construct, the flowchart in Figure 4.143 outputs “Yes” if the input text is the same as the special phrase “P@55w0rd”, otherwise it outputs “No”:
#
# ![image.png](data:image/png;base64,...)

# %%
text = input("Enter text: ")
if text == "P@55w0rd":
  print("Yes")
else:
  print("No")

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
text = input("Enter text: ")
if text == "P@55w0rd":
  print("Yes")
  print("Correct Password")
else:
  print("No")
  print("Wrong Password")
print("Goodbye")

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Option 1
text = input("Enter text: ")
if text == "":
  print("Blank Input Not Allowed")
else:
  if text == "P@55w0rd":
    print("Yes")
    print("Correct Password")
  else:
    print("No")
    print("Wrong Password")
print("Goodbye")

# Option 2
"""
text = input("Enter text: ")
if text == "":
  print("Blank Input Not Allowed")
elif text == "P@55w0rd":
  print("Yes")
  print("Correct Password")
else:
  print("No")
  print("Wrong Password")
print("Goodbye")

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
name = input("Enter name: ")
if "Evil" in name:
  name = "*** CENSORED ***"
print("You are " + name)
# Out:
# Enter name:  Evil man
# You are *** CENSORED ***

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
name = ""
while name == "":
  name = input("Enter name: ")
print("Hello " + name)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
items = [1, 2, 4, 8, 16, 32]
index = 0
while index < len(items):
  print(items[index])
  index = index + 1

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
words = ["Code", "Computing", "Future", "Cow", "Thinking"]
index = 0
while index < len(words):
  if words[index][0] != 'C':
    index = index + 1
    continue
  print("C is for " + words[index])
  index = index + 1

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
words = ["Code", "Computing", "Future", "Cow", "Thinking"]
index = 0
while index < len(words):
  if words[index][0] != 'C':
    break
  print("C is for " + words[index])
  index = index + 1
# Out:
# C is for Code
# C is for Computing

# %% [markdown]
# ---
# # **Practice**
# ---

# %%
# (1) Draw the flowchart that describe the following code:


MAGIC_WORDS = "Simon says "
QUIT_COMMAND = "Quit"

print("Enter \"" + QUIT_COMMAND + "\" to end the game.")
while True:
  command = input("Enter command: ")
  if command == QUIT_COMMAND:
    break
  elif command[:len(MAGIC_WORDS)] != MAGIC_WORDS:
    print("We ignore the command")
    continue
  print("We " + command[len(MAGIC_WORDS):])
print("Thanks for playing!")
# Out:
# Enter "Quit" to end the game.
# Enter command:  Quit
# Thanks for playing!

# %% [markdown]
# ![Screenshot 2024-05-01 at 12.09.06 AM.png](attachment:72ff5318-033f-4422-8aa5-d6eee5ed6971.png)

# %% [markdown]
# (2) Translate the following flowcharts to a Python program:

# %% [markdown]
# (a)
#
#  ![image.png](data:image/png;base64,...)

# %%
# (a)
number = int(input())
if number%2==0: print('Even') 
else: print('Odd')
# Out:
#  -6
# Even

# %% [markdown]
# (b)
# ![image.png](data:image/png;base64,...)

# %%
# (b)
#finds remainder

try:
    dividend, divisor = int(input()), int(input())
except ValueError:
    print('top skibidi behaviour g')
    dividend, divisor = '', ' '

while dividend >= divisor:
    dividend-=divisor

print(dividend)
# Out:
#  sfnj
# top skibidi behaviour g

# %% [markdown]
# (c)
# ![image.png](data:image/png;base64,...)

# %%
# (c)
#prints every step (minus one) needed for start to surpass stop  (first step is at start)

try:
    start, stop, step = int(input()), int(input()), int(input())
except ValueError:
    print('top skibidi behaviour g')
    start, stop = 0, 0

current = start

while current < stop:
    print(current)
    current+=step
# Out:
#  1
#  200
#  100
# 1
# 101
