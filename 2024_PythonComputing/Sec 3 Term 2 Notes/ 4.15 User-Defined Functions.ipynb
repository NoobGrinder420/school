# %% [markdown]
# Besides Python’s built-in functions, you can also write your own functions. These are called user-defined
# functions (UDFs).
#
# To define a UDF, we first need to choose its name. The name must be a valid Python identifier that follows the same rules described previously for variable names  The UDF’s name should also be different from any existing variable or function names. Otherwise, the UDF will overwrite the existing value or function associated with that name.

# %%
def hello():
  # This code does not get run at all
  print('Hello, World!')

# %%
def hello():
  # Say hello
  print('Hello, World!')

hello()
hello()
hello()
# Out:
# Hello, World!
# Hello, World!
# Hello, World!

# %% [markdown]
# **Parameters**
# : Special variable in a UDF that an argument is
# assigned to when the UDF is called
#
# **Signature (programming)**
# : The first line of a UDF that specifies the UDF’s name
# and its parameters

# %%
def get_answer(prompt, reply):
  answer = input(prompt)
  print(reply)
  return answer

answer1 = get_answer('What is your name?', 'Thanks!')
answer2 = get_answer('What is your age?', 'Thanks again!')
answer3 = get_answer('What is your hobbt?', 'Thank you!')

print('Your answers were...')
print(answer1, answer2, answer3)
# Out:
# What is your name? noob
# Thanks!
# What is your age? 20 months
# Thanks again!
# What is your hobbt? balls
# Thank you!
# Your answers were...
# noob 20 months balls

# %% [markdown]
# Line 4 shows that a UDF can provide a return value using the return keyword. When Python encounters a return instruction, the function immediately ends and the original function call is treated as the provided return value.
#
# If no return instruction is encountered before the function body ends, then the default return value is None and the original function call is also treated as None.

# %% [markdown]
# ![Screenshot 2024-04-08 at 10.31.10 AM.png](data:image/png;base64,...)

# %% [markdown]
# **Local variable**
# A variable that is created inside a UDF
# and can only be used in the UDF’s
# body

# %%
PI = 3.14159

def area_of_circle(radius):
  area = PI * radius ** 2
  # Both radius and area are valid variables here
  return area

print(area_of_circle(2))
# However, radius and area are NOT valid variables here

# %% [markdown]
# Notice that area_of_circle() uses the constant PI that is defined outside of the function body. Besides local variables, the code inside a function body also has read access to the global variables, constants and functions that are defined outside of the function.
#
# **Global variable**
# : A variable that is created outside of a UDF
# and is readable from the UDF’s body if its
# name is not hidden by a local variable

# %%
def good_example(num1, num2): # num1 and num2 are local
  return num1 + num2          # OK

def bad_example():            # num1 and num2 are global
  return num1 + num2          # Don't do this

num1 = 19
num2 = 65

print(good_example(20, 17))
print(bad_example())
# Out:
# 37
# 84

# %% [markdown]
# While they have the same names, it is important to understand that the local variables named num1 and num2 on lines 1 and 2 are completely separate variables from the global variables named num1 and num2
# on lines 5, 7 and 8.

# %% [markdown]
# UDFs have several advantages:
#  - Code that is repeated in different locations of the program can be put in UDFs. The repeated code can then be replaced with shorter function calls.
#  - When designing an algorithm, the solution to each sub-problem can be placed in a separate UDF. Each UDF will be smaller than the main program and thus can be more easily understood.
#  - When working in a team, different programmers can be given responsibility for diff erent UDFs so they can all work concurrently.
#  - Each UDF can be tested separately and more thoroughly with different inputs compared to a single large program with no UDFs.

# %% [markdown]
# ---
# # **Practice**
# ---

# %% [markdown]
# Task: Create a simple calculator program that performs basic arithmetic operations (addition, subtraction, multiplication, division) based on user input.
#
# - Define a function for each arithmetic operation (e.g., add, subtract, multiply, divide).
# - Implement a main function that takes user input for two numbers and the desired operation, and then calls the appropriate function based on the operation chosen.
# - Display the result of the operation to the user.

# %%
# Type your code here
def ADD(NUM1,NUM2):
    return(NUM1+NUM2)
def SUBTRACT(NUM1,NUM2):
    return(NUM1-NUM2)
def MULTIPLY(NUM1,NUM2):
    return(NUM1*NUM2)
def DIVIDE(NUM1,NUM2):
    if NUM2 == 0:
        return("whopper")
    else:
        return(NUM1/NUM2)

num1 = int(input('num1:'))
DesFunc = input('+, -, *, /: ')
num2 = int(input('num2:'))


if DesFunc == "+":
    print(ADD(num1,num2))
elif DesFunc == "-":
    print(SUBTRACT(num1,num2))
elif DesFunc == "/":
    print(DIVIDE(num1,num2))
elif DesFunc == "*":
    print(MULTIPLY(num1,num2))
# Out:
# num1: 2
# +, -, *, /:  +
# num2: 3
# 5

# %% [markdown]
# ###
